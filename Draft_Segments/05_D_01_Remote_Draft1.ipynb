# %% [markdown]
# # Remote

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import datetime
import matplotlib.dates as mdates

from scipy import stats
from matplotlib.dates import DateFormatter
from IPython.display import display

# %% [markdown]
# # Load and Display Raw Data

# %%
db_survey = sqlite3.connect(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\TechMentalHealth\\DataSet\\mental_health.sqlite"
)

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Colors

# %%
ord_color = "bisque"
spec_lev1 = "crimson"
spec_lev2 = "orangered"
spec_lev3 = "lightcoral"
male_color = "royalblue"
female_color = "pink"
graph_color1 = "indianred"
graph_color2 = "slategrey"

# %% [markdown]
# # Answers

# %%
df_answers = pd.read_sql_query("SELECT * FROM Answer", db_survey)
df_answers.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0         37      2014       1           1
# 1         44      2014       2           1
# 2         32      2014       3           1
# 3         31      2014       4           1
# 4         31      2014       5           1

# %% [markdown]
# # Tech Workers in Tech Companies

# %%
df_Answer9 = pd.read_sql_query(
    "SELECT USERID FROM Answer where QuestionID = 9 AND AnswerText = '1'",
    db_survey
)

# %%
df_Answer9.count()
# Out:
# UserID    2888
# dtype: int64

# %%
df_Answer13 = pd.read_sql_query(
    "SELECT USERID FROM Answer where QuestionID = 13 AND AnswerText = '1'",
    db_survey
)

# %%
df_Answer13.count()
# Out:
# UserID    1471
# dtype: int64

# %%
df_TechinTech = pd.merge(df_Answer13, df_Answer9 , on='UserID', how='inner')

# %%
Total_TechinTech = df_TechinTech.count()
Total_TechinTech
# Out:
# UserID    909
# dtype: int64

# %% [markdown]
# # 93
# Do you work remotely at least 50% of the time?
# Do you work remotely?

# %%
df_Answer93 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 93",
    db_survey
)
df_Answer93.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0         No      2014       1          93
# 1         No      2014       2          93
# 2         No      2014       3          93
# 3         No      2014       4          93
# 4        Yes      2014       5          93

# %%
df_Answer93.count()
# Out:
# AnswerText    1260
# SurveyID      1260
# UserID        1260
# QuestionID    1260
# dtype: int64

# %%
df_Answer93_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 93",
    db_survey
)
df_Answer93_Distinct
# Out:
#   AnswerText
# 0         No
# 1        Yes

# %%
df_Answer93_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 93 AND AnswerText = 'No'",
    db_survey
)
df_Answer93_Yes
# Out:
#      UserID
# 0         1
# 1         2
# 2         3
# 3         4
# 4         6
# 5         9
# 6        10
# 7        13
# 8        14
# 9        15
# 10       16
# 11       18
# 12       21
# 13       24
# 14       25
# 15       26
# 16       27
# 17       30
# 18       35
# 19       36
# 20       37
# 21       38
# 22       39
# 23       41
# 24       43
# 25       44
# 26       45
# 27       46
# 28       47
# 29       48
# 30       49
# 31       50
# 32       51
# 33       55
# 34       56
# 35       59
# 36       61
# 37       63
# 38       64
# 39       65
# 40       71
# 41       72
# 42       73
# 43       74
# 44       75
# 45       76
# 46       82
# 47       83
# 48       85
# 49       86
# 50       87
# 51       89
# 52       90
# 53       91
# 54       92
# 55       93
# 56       95
# 57       96
# 58       97
# 59       98
# 60       99
# 61      100
# 62      101
# 63      102
# 64      103
# 65      105
# 66      106
# 67      108
# 68      110
# 69      111
# ...

# %%
df_Answer93_Yes_TechinTech = pd.merge(df_TechinTech, df_Answer93_Yes, on='UserID', how='inner')

# %%
df_Answer93_Yes_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# ## 118
# Do you work remotely?

# %%
df_Answer118 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 118",
    db_survey
)
df_Answer118.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0  Sometimes      2016    1261         118
# 1      Never      2016    1262         118
# 2     Always      2016    1263         118
# 3  Sometimes      2016    1264         118
# 4  Sometimes      2016    1265         118

# %%
df_Answer118.count()
# Out:
# AnswerText    1433
# SurveyID      1433
# UserID        1433
# QuestionID    1433
# dtype: int64

# %%
df_Answer118_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 118",
    db_survey
)
df_Answer118_Distinct
# Out:
#   AnswerText
# 0  Sometimes
# 1      Never
# 2     Always

# %%
df_Answer118_Always = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 118 AND AnswerText = 'Always'",
    db_survey
)
df_Answer118_Always
# Out:
#      UserID
# 0      1263
# 1      1268
# 2      1270
# 3      1273
# 4      1275
# 5      1277
# 6      1279
# 7      1297
# 8      1300
# 9      1302
# 10     1310
# 11     1315
# 12     1324
# 13     1328
# 14     1335
# 15     1340
# 16     1354
# 17     1357
# 18     1366
# 19     1368
# 20     1372
# 21     1375
# 22     1386
# 23     1398
# 24     1401
# 25     1403
# 26     1406
# 27     1412
# 28     1413
# 29     1414
# 30     1415
# 31     1416
# 32     1419
# 33     1429
# 34     1432
# 35     1433
# 36     1438
# 37     1440
# 38     1451
# 39     1458
# 40     1461
# 41     1462
# 42     1465
# 43     1467
# 44     1468
# 45     1469
# 46     1470
# 47     1472
# 48     1476
# 49     1485
# 50     1486
# 51     1488
# 52     1494
# 53     1503
# 54     1504
# 55     1508
# 56     1512
# 57     1515
# 58     1525
# 59     1531
# 60     1538
# 61     1541
# 62     1544
# 63     1547
# 64     1562
# 65     1565
# 66     1566
# 67     1569
# 68     1570
# 69     1574
# ...

# %%
df_Answer118_Always_TechinTech = pd.merge(df_TechinTech, df_Answer118_Always, on='UserID', how='inner')

# %%
df_Answer118_Always_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %%
df_Answer118_Sometimes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 118 AND AnswerText = 'Sometimes'",
    db_survey
)
df_Answer118_Sometimes.count()
# Out:
# UserID    757
# dtype: int64

# %%
df_Answer118_Sometimes_TechinTech = pd.merge(df_TechinTech, df_Answer118_Sometimes, on='UserID', how='inner')

# %%
df_Answer118_Sometimes_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %%
df_Answer118_Never = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 118 AND AnswerText = 'Never'",
    db_survey
)
df_Answer118_Never.count()
# Out:
# UserID    333
# dtype: int64

# %%
df_Answer118_Never_TechinTech = pd.merge(df_TechinTech, df_Answer118_Never, on='UserID', how='inner')

# %%
df_Answer118_Never_TechinTech.count()
# Out:
# UserID    0
# dtype: int64
