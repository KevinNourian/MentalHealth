# %% [markdown]
# # Openness

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import datetime
import matplotlib.dates as mdates

from scipy import stats
from matplotlib.dates import DateFormatter
from IPython.display import display

# %% [markdown]
# # Load and Display Raw Data

# %%
db_survey = sqlite3.connect(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\TechMentalHealth\\DataSet\\mental_health.sqlite"
)

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Colors

# %%
ord_color = "bisque"
spec_lev1 = "crimson"
spec_lev2 = "orangered"
spec_lev3 = "lightcoral"
male_color = "royalblue"
female_color = "pink"
graph_color1 = "indianred"
graph_color2 = "slategrey"

# %% [markdown]
# # Answers

# %%
df_answers = pd.read_sql_query("SELECT * FROM Answer", db_survey)
df_answers.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0         37      2014       1           1
# 1         44      2014       2           1
# 2         32      2014       3           1
# 3         31      2014       4           1
# 4         31      2014       5           1

# %% [markdown]
# # Tech Workers in Tech Companies

# %%
df_Answer9 = pd.read_sql_query(
    "SELECT USERID FROM Answer where QuestionID = 9 AND AnswerText = '1'",
    db_survey
)

# %%
df_Answer9.count()
# Out:
# UserID    2888
# dtype: int64

# %%
df_Answer13 = pd.read_sql_query(
    "SELECT USERID FROM Answer where QuestionID = 13 AND AnswerText = '1'",
    db_survey
)

# %%
df_Answer13.count()
# Out:
# UserID    1471
# dtype: int64

# %%
df_TechinTech = pd.merge(df_Answer13, df_Answer9 , on='UserID', how='inner')

# %%
df_TechinTech
# Out:
#      UserID
# 0      2694
# 1      2695
# 2      2696
# 3      2697
# 4      2700
# 5      2701
# 6      2705
# 7      2706
# 8      2707
# 9      2712
# 10     2714
# 11     2717
# 12     2718
# 13     2719
# 14     2724
# 15     2725
# 16     2726
# 17     2730
# 18     2733
# 19     2736
# 20     2737
# 21     2738
# 22     2744
# 23     2745
# 24     2747
# 25     2748
# 26     2751
# 27     2752
# 28     2754
# 29     2757
# 30     2759
# 31     2760
# 32     2761
# 33     2762
# 34     2763
# 35     2769
# 36     2772
# 37     2773
# 38     2774
# 39     2775
# 40     2776
# 41     2777
# 42     2778
# 43     2779
# 44     2781
# 45     2783
# 46     2784
# 47     2785
# 48     2786
# 49     2790
# 50     2794
# 51     2795
# 52     2796
# 53     2800
# 54     2802
# 55     2804
# 56     2807
# 57     2808
# 58     2809
# 59     2810
# 60     2812
# 61     2813
# 62     2814
# 63     2815
# 64     2818
# 65     2819
# 66     2820
# 67     2821
# 68     2824
# 69     2825
# ...

# %%
Total_TechinTech = df_TechinTech.count()
Total_TechinTech
# Out:
# UserID    909
# dtype: int64

# %% [markdown]
# # 12
# Would you bring up a mental health issue with a potential employer in an interview?

# %%
df_Answer12 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 12",
    db_survey
)
df_Answer12.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0         No      2014       1          12
# 1         No      2014       2          12
# 2        Yes      2014       3          12
# 3      Maybe      2014       4          12
# 4        Yes      2014       5          12

# %%
df_Answer12.count()
# Out:
# AnswerText    4218
# SurveyID      4218
# UserID        4218
# QuestionID    4218
# dtype: int64

# %%
df_Answer12_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 12",
    db_survey
)
df_Answer12_Distinct
# Out:
#   AnswerText
# 0         No
# 1        Yes
# 2      Maybe

# %%
df_Answer12_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 12 AND AnswerText = 'Yes'",
    db_survey
)
df_Answer12_Yes.count()
# Out:
# UserID    231
# dtype: int64

# %%
df_Answer12TechinTech = pd.merge(df_TechinTech, df_Answer12_Yes, on='UserID', how='inner')

# %%
df_Answer12TechinTech.count()
# Out:
# UserID    51
# dtype: int64

# %% [markdown]
# # 18
# Would you feel comfortable discussing a mental health issue with a coworker?

# %%
df_Answer18 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 18",
    db_survey
)

# %%
df_Answer18.count()
# Out:
# AnswerText    2958
# SurveyID      2958
# UserID        2958
# QuestionID    2958
# dtype: int64

# %%
df_Answer18.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0      Maybe      2016    1261          18
# 1      Maybe      2016    1262          18
# 2      Maybe      2016    1263          18
# 3         -1      2016    1264          18
# 4      Maybe      2016    1265          18

# %%
df_Answer18_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 18",
    db_survey
)
df_Answer18_Distinct
# Out:
#   AnswerText
# 0      Maybe
# 1         -1
# 2        Yes
# 3         No

# %%
df_Answer18_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 18 AND AnswerText = 'Yes'",
    db_survey
)
df_Answer18_Yes.count()
# Out:
# UserID    682
# dtype: int64

# %%
df_Answer18TechinTech = pd.merge(df_TechinTech, df_Answer18_Yes, on='UserID', how='inner')

# %%
df_Answer18TechinTech.count()
# Out:
# UserID    312
# dtype: int64

# %% [markdown]
# # 99
# Would you be willing to discuss a mental health issue with your coworkers?

# %%
df_Answer99 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 99",
    db_survey
)

# %%
df_Answer99.count()
# Out:
# AnswerText    1260
# SurveyID      1260
# UserID        1260
# QuestionID    1260
# dtype: int64

# %%
df_Answer99_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 99",
    db_survey
)
df_Answer99_Distinct
# Out:
#      AnswerText
# 0  Some of them
# 1            No
# 2           Yes

# %%
df_Answer99_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 99 AND AnswerText = 'Yes'",
    db_survey
)
df_Answer99_Yes.count()
# Out:
# UserID    225
# dtype: int64

# %%
df_Answer99TechinTech = pd.merge(df_TechinTech, df_Answer99_Yes, on='UserID', how='inner')

# %%
df_Answer99TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# # 114
# Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue? <BR>
# (No answer gives results)

# %%
df_Answer114 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 114",
    db_survey
)

# %%
df_Answer114.count()
# Out:
# AnswerText    1433
# SurveyID      1433
# UserID        1433
# QuestionID    1433
# dtype: int64

# %%
df_Answer114.head()
# Out:
#                      AnswerText  SurveyID  UserID  QuestionID
# 0  No, I don't think they would      2016    1261         114
# 1  No, I don't think they would      2016    1262         114
# 2                         Maybe      2016    1263         114
# 3                         Maybe      2016    1264         114
# 4                         Maybe      2016    1265         114

# %%
df_Answer114_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 114",
    db_survey
)
df_Answer114_Distinct
# Out:
#                      AnswerText
# 0  No, I don't think they would
# 1                         Maybe
# 2                  Yes, they do
# 3       Yes, I think they would
# 4               No, they do not

# %%
df_Answer114_No = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 114 AND AnswerText = 'Yes, I think they would'",
    db_survey
)
df_Answer114_No.count()
# Out:
# UserID    403
# dtype: int64

# %%
df_Answer114TechinTech = pd.merge(df_TechinTech, df_Answer114_No, on='UserID', how='inner')

# %%
df_Answer114TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# # 19
# Would you feel comfortable discussing a mental health issue with a direct supervisor?

# %%
df_Answer19 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 19",
    db_survey
)

# %%
df_Answer19.count()
# Out:
# AnswerText    2958
# SurveyID      2958
# UserID        2958
# QuestionID    2958
# dtype: int64

# %%
df_Answer19.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0        Yes      2016    1261          19
# 1        Yes      2016    1262          19
# 2      Maybe      2016    1263          19
# 3         -1      2016    1264          19
# 4         No      2016    1265          19

# %%
df_Answer19_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 19",
    db_survey
)
df_Answer19_Distinct
# Out:
#   AnswerText
# 0        Yes
# 1      Maybe
# 2         -1
# 3         No

# %%
df_Answer19_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 19 AND AnswerText = 'Yes'",
    db_survey
)
df_Answer19_Yes.count()
# Out:
# UserID    932
# dtype: int64

# %%
df_Answer19TechinTech = pd.merge(df_TechinTech, df_Answer19_Yes, on='UserID', how='inner')

# %%
df_Answer19TechinTech.count()
# Out:
# UserID    372
# dtype: int64

# %% [markdown]
# # 28
# Would you be willing to discuss your mental health with your direct supervisor(s)?

# %%
df_Answer28 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 28",
    db_survey
)

# %%
df_Answer28.count()
# Out:
# AnswerText    2958
# SurveyID      2958
# UserID        2958
# QuestionID    2958
# dtype: int64

# %%
df_Answer28_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 28",
    db_survey
)
df_Answer28_Distinct
# Out:
#                              AnswerText
# 0         Some of my previous employers
# 1                          I don't know
# 2  No, at none of my previous employers
# 3  Yes, at all of my previous employers
# 4                                    -1
# 5   Yes, all of my previous supervisors
# 6   No, none of my previous supervisors
# 7       Some of my previous supervisors

# %%
df_Answer28 = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 104 AND AnswerText = 'No, none of my previous supervisors'",
    db_survey
)
df_Answer28.count()
# Out:
# UserID    0
# dtype: int64

# %%
df_Answer28_TechinTech = pd.merge(df_TechinTech, df_Answer28, on='UserID', how='inner')

# %%
df_Answer28_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# # 100
# Would you be willing to discuss a mental health issue with your direct supervisor(s)?
# (No TechinTech answered this question)

# %%
df_Answer100 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 100",
    db_survey
)

# %%
df_Answer100.count()
# Out:
# AnswerText    1260
# SurveyID      1260
# UserID        1260
# QuestionID    1260
# dtype: int64

# %%
df_Answer100_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 100",
    db_survey
)
df_Answer100_Distinct
# Out:
#      AnswerText
# 0           Yes
# 1            No
# 2  Some of them

# %%
df_Answer100_No = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 100 AND AnswerText = 'Some of them'",
    db_survey
)
df_Answer100_No.count()
# Out:
# UserID    350
# dtype: int64

# %%
df_Answer100_TechinTech = pd.merge(df_TechinTech, df_Answer100_No, on='UserID', how='inner')

# %%
df_Answer100_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# # 104
# Do you think that discussing a mental health disorder with your employer would have negative consequences?
# (No TechinTech answered this question)

# %%
df_Answer104 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 104",
    db_survey
)

# %%
df_Answer104.count()
# Out:
# AnswerText    1433
# SurveyID      1433
# UserID        1433
# QuestionID    1433
# dtype: int64

# %%
df_Answer104_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 104",
    db_survey
)
df_Answer104_Distinct
# Out:
#   AnswerText
# 0         No
# 1      Maybe
# 2         -1
# 3        Yes

# %%
df_Answer104_No = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 104 AND AnswerText = 'Maybe'",
    db_survey
)
df_Answer104_No.count()
# Out:
# UserID    487
# dtype: int64

# %%
df_Answer104_TechinTech = pd.merge(df_TechinTech, df_Answer104_No, on='UserID', how='inner')

# %%
df_Answer104_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# # 30
# How willing would you be to share with friends and family that you have a mental illness?

# %%
df_Answer30 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 30",
    db_survey
)
df_Answer30.head()
# Out:
#       AnswerText  SurveyID  UserID  QuestionID
# 0  Somewhat open      2016    1261          30
# 1  Somewhat open      2016    1262          30
# 2  Somewhat open      2016    1263          30
# 3        Neutral      2016    1264          30
# 4  Somewhat open      2016    1265          30

# %%
df_Answer30.count()
# Out:
# AnswerText    2958
# SurveyID      2958
# UserID        2958
# QuestionID    2958
# dtype: int64

# %%
df_Answer30_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 30",
    db_survey
)
df_Answer30_Distinct
# Out:
#                                               AnswerText
# 0                                          Somewhat open
# 1                                                Neutral
# 2  Not applicable to me (I do not have a mental illness)
# 3                                              Very open
# 4                                        Not open at all
# 5                                      Somewhat not open

# %% [markdown]
# ## Very Open

# %%
df_Answer30_Very = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 30 AND AnswerText = 'Very open'",
    db_survey
)
df_Answer30_Very.count()
# Out:
# UserID    1104
# dtype: int64

# %%
df_Answer30_Very_TechinTech = pd.merge(df_TechinTech, df_Answer30_Very, on='UserID', how='inner')

# %%
df_Answer30_Very_TechinTech.count()
# Out:
# UserID    523
# dtype: int64

# %% [markdown]
# ## Somewhat open

# %%
df_Answer30_Somewhat = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 30 AND AnswerText = 'Somewhat open'",
    db_survey
)
df_Answer30_Somewhat.count()
# Out:
# UserID    791
# dtype: int64

# %%
df_Answer30_Somewhat_TechinTech = pd.merge(df_TechinTech, df_Answer30_Somewhat, on='UserID', how='inner')

# %%
df_Answer30_Somewhat_TechinTech.count()
# Out:
# UserID    94
# dtype: int64

# %% [markdown]
# ## Neutral

# %%
df_Answer30_Neutral = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 30 AND AnswerText = 'Neutral'",
    db_survey
)
df_Answer30_Neutral.count()
# Out:
# UserID    329
# dtype: int64

# %%
df_Answer30_Neutral_TechinTech = pd.merge(df_TechinTech, df_Answer30_Neutral, on='UserID', how='inner')

# %%
df_Answer30_Neutral_TechinTech.count()
# Out:
# UserID    114
# dtype: int64

# %% [markdown]
# # 106
# If you have revealed a mental health issue to a client or business contact, do you believe it has impacted you negatively?
# (No TechinTech answered this question)

# %%
df_Answer106 = pd.read_sql_query(
    "SELECT * FROM Answer where QuestionID = 106",
    db_survey
)

# %%
df_Answer106.count()
# Out:
# AnswerText    1433
# SurveyID      1433
# UserID        1433
# QuestionID    1433
# dtype: int64

# %%
df_Answer106.head()
# Out:
#      AnswerText  SurveyID  UserID  QuestionID
# 0            -1      2016    1261         106
# 1            -1      2016    1262         106
# 2            -1      2016    1263         106
# 3  I'm not sure      2016    1264         106
# 4            -1      2016    1265         106

# %%
df_Answer106_Distinct = pd.read_sql_query(
    "SELECT DISTINCT AnswerText FROM Answer where QuestionID = 106",
    db_survey
)
df_Answer106_Distinct
# Out:
#      AnswerText
# 0            -1
# 1  I'm not sure
# 2           Yes
# 3            No

# %% [markdown]
# ## Yes

# %%
df_Answer106_Yes = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 106 AND AnswerText = 'Yes'",
    db_survey
)
df_Answer106_Yes.count()
# Out:
# UserID    36
# dtype: int64

# %%
df_Answer106_Yes_TechinTech = pd.merge(df_TechinTech, df_Answer106_Yes, on='UserID', how='inner')

# %%
df_Answer106_Yes_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# ## No Response

# %%
df_Answer106_NR = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 106 AND AnswerText = '-1'",
    db_survey
)

# %%
df_Answer106_NR_TechinTech = pd.merge(df_TechinTech, df_Answer106_NR, on='UserID', how='inner')

# %%
df_Answer106_NR_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# ## No

# %%
df_Answer106_No = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 106 AND AnswerText = 'No'",
    db_survey
)
df_Answer106_No.count()
# Out:
# UserID    42
# dtype: int64

# %%
df_Answer106_No_TechinTech = pd.merge(df_TechinTech, df_Answer106_No, on='UserID', how='inner')

# %%
df_Answer106_No_TechinTech.count()
# Out:
# UserID    0
# dtype: int64

# %% [markdown]
# ## I'm not sure

# %%
df_Answer106_NotSure = pd.read_sql_query(
    "SELECT UserID FROM Answer where QuestionID = 106 AND AnswerText = 'I''m not sure'",
    db_survey
)
df_Answer106_NotSure.count()
# Out:
# UserID    66
# dtype: int64

# %%
df_Answer106_NR_TechinTech = pd.merge(df_TechinTech, df_Answer106_NR, on='UserID', how='inner')

# %%
df_Answer106_NR_TechinTech.count()
# Out:
# UserID    0
# dtype: int64
