# %% [markdown]
# # Data Cleaning Draft 1

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import datetime
import matplotlib.dates as mdates

from scipy import stats
from matplotlib.dates import DateFormatter
from IPython.display import display

# %% [markdown]
# # Load and Display Raw Data

# %%
db_survey = sqlite3.connect(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\TechMentalHealth\\DataSet\\mental_health.sqlite"
)

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Questions

# %%
df_questions = pd.read_sql_query("SELECT * FROM Question", db_survey)

# %%
df_questions.count().to_frame()
df_questions = df_questions.rename(
    columns={"questiontext": "QuestionText", "questionid": "QuestionID"}
)
df_questions.style.set_properties(**{"text-align": "left"})
# Out:
# <style type="text/css">
# #T_7e00c_row0_col0, #T_7e00c_row0_col1, #T_7e00c_row1_col0, #T_7e00c_row1_col1, #T_7e00c_row2_col0, #T_7e00c_row2_col1, #T_7e00c_row3_col0, #T_7e00c_row3_col1, #T_7e00c_row4_col0, #T_7e00c_row4_col1, #T_7e00c_row5_col0, #T_7e00c_row5_col1, #T_7e00c_row6_col0, #T_7e00c_row6_col1, #T_7e00c_row7_col0, #T_7e00c_row7_col1, #T_7e00c_row8_col0, #T_7e00c_row8_col1, #T_7e00c_row9_col0, #T_7e00c_row9_col1, #T_7e00c_row10_col0, #T_7e00c_row10_col1, #T_7e00c_row11_col0, #T_7e00c_row11_col1, #T_7e00c_row12_col0, #T_7e00c_row12_col1, #T_7e00c_row13_col0, #T_7e00c_row13_col1, #T_7e00c_row14_col0, #T_7e00c_row14_col1, #T_7e00c_row15_col0, #T_7e00c_row15_col1, #T_7e00c_row16_col0, #T_7e00c_row16_col1, #T_7e00c_row17_col0, #T_7e00c_row17_col1, #T_7e00c_row18_col0, #T_7e00c_row18_col1, #T_7e00c_row19_col0, #T_7e00c_row19_col1, #T_7e00c_row20_col0, #T_7e00c_row20_col1, #T_7e00c_row21_col0, #T_7e00c_row21_col1, #T_7e00c_row22_col0, #T_7e00c_row22_col1, #T_7e00c_row23_col0, #T_7e00c_row23_col1, #T_7e00c_row24_col0, #T_7e00c_row24_col1, #T_7e00c_row25_col0, #T_7e00c_row25_col1, #T_7e00c_row26_col0, #T_7e00c_row26_col1, #T_7e00c_row27_col0, #T_7e00c_row27_col1, #T_7e00c_row28_col0, #T_7e00c_row28_col1, #T_7e00c_row29_col0, #T_7e00c_row29_col1, #T_7e00c_row30_col0, #T_7e00c_row30_col1, #T_7e00c_row31_col0, #T_7e00c_row31_col1, #T_7e00c_row32_col0, #T_7e00c_row32_col1, #T_7e00c_row33_col0, #T_7e00c_row33_col1, #T_7e00c_row34_col0, #T_7e00c_row34_col1, #T_7e00c_row35_col0, #T_7e00c_row35_col1, #T_7e00c_row36_col0, #T_7e00c_row36_col1, #T_7e00c_row37_col0, #T_7e00c_row37_col1, #T_7e00c_row38_col0, #T_7e00c_row38_col1, #T_7e00c_row39_col0, #T_7e00c_row39_col1, #T_7e00c_row40_col0, #T_7e00c_row40_col1, #T_7e00c_row41_col0, #T_7e00c_row41_col1, #T_7e00c_row42_col0, #T_7e00
">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e00c_level0_col0" class="col_heading level0 col0" >QuestionText</th>
#       <th id="T_7e00c_level0_col1" class="col_heading level0 col1" >QuestionID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e00c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e00c_row0_col0" class="data row0 col0" >What is your age?</td>
#       <td id="T_7e00c_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e00c_row1_col0" class="data row1 col0" >What is your gender?</td>
#       <td id="T_7e00c_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e00c_row2_col0" class="data row2 col0" >What country do you live in?</td>
#       <td id="T_7e00c_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e00c_row3_col0" class="data row3 col0" >If you live in the United States, which state or territory do you live in?</td>
#       <td id="T_7e00c_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e00c_row4_col0" class="data row4 col0" >Are you self-employed?</td>
#       <td id="T_7e00c_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e00c_row5_col0" class="data row5 col0" >Do you have a family history of mental illness?</td>
#       <td id="T_7e00c_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e00c_row6_col0" class="data row6 col0" >Have you ever sought treatment for a mental health disorder from a mental health professional?</td>
#       <td id="T_7e00c_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7e00c_row7_col0" class="data row7 col0" >How many employees does your company or organization have?</td>
#       <td id="T_7e00c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7e00c_row8_col0" class="data row8 col0" >Is your employer primarily a tech company/organization?</td>
#       <td id="T_7e00c_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7e00c_row9_col0" class="data row9 col0" >Does your employer provide mental health benefits as part of healthcare coverage?</td>
#       <td id="T_7e00c_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7e00c_row10_col0" class="data row10 col0" >Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?</td>
#       <td id="T_7e00c_row10_col1" class="data row10 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7e00c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7e00c_row11_col0" class="data row11 col0" >Would you bring up a mental health

# %%
df_questions.drop(
    df_questions.index[
        [
            3,
            7,
            21,
            22,
            23,
            24,
            25,
            26,
            28,
            34,
            35,
            37,
            40,
            41,
            45,
            47,
            48,
            49,
            55,
            56,
            57,
            58,
            59,
            60,
            61,
            62,
            63,
            68,
            70,
            72,
            73,
            74,
            75,
            87,
            89,
            94,
            95,
            96,
            97,
            98,
            101,
            102,
            103,
        ]
    ],
    inplace=True,
)

# %%
df_questions.shape[0]
# Out:
# 62

# %% [markdown]
# # Answers

# %%
df_answers = pd.read_sql_query("SELECT * FROM Answer", db_survey)

# %%
df_answers.head()
# Out:
#   AnswerText  SurveyID  UserID  QuestionID
# 0         37      2014       1           1
# 1         44      2014       2           1
# 2         32      2014       3           1
# 3         31      2014       4           1
# 4         31      2014       5           1

# %%
df_answers = df_answers[["SurveyID", "UserID", "QuestionID", "AnswerText"]]

# %%
df_answers.head()
# Out:
#    SurveyID  UserID  QuestionID AnswerText
# 0      2014       1           1         37
# 1      2014       2           1         44
# 2      2014       3           1         32
# 3      2014       4           1         31
# 4      2014       5           1         31

# %% [markdown]
# # Merged Tables

# %%
df_combined = pd.merge(df_questions, df_answers, on="QuestionID", how="inner")

# %%
df_combined = df_combined[
    ["SurveyID", "UserID", "QuestionID", "QuestionText", "AnswerText"]
]
df_combined.head()
# Out:
#    SurveyID  UserID  QuestionID       QuestionText AnswerText
# 0      2014       1           1  What is your age?         37
# 1      2014       2           1  What is your age?         44
# 2      2014       3           1  What is your age?         32
# 3      2014       4           1  What is your age?         31
# 4      2014       5           1  What is your age?         31

# %%
df_combined.shape[0]
# Out:
# 147749

# %% [markdown]
# # QuestionID 1: What is your age?

# %%
df_age = pd.read_sql_query(
    "SELECT AnswerText FROM Answer where QuestionID = 1", db_survey
)

# %%
df_age["AnswerText"] = df_age["AnswerText"].astype(int)

# %%
df_age.sort_values("AnswerText", inplace=True)

# %%
df_age = df_age[df_age.AnswerText > 18]
df_age = df_age[df_age.AnswerText < 75]

# %%
df_value_counts = df_age.AnswerText.value_counts()
df_age_counts = pd.DataFrame(df_value_counts)
df_age_counts = df_value_counts.reset_index()

# %%
df_age_counts = df_age_counts.rename(columns={"index": "Age", "AnswerText": "Count"})
df_age_counts = df_age_counts.set_index("Age")
df_age_counts.head()
# Out:
#      Count
# Age
# 30     250
# 29     229
# 32     227
# 31     223
# 28     220

# %% [markdown]
# # QuestionID 2: What is your gender?

# %%
df_gender = pd.read_sql_query(
    "SELECT AnswerText FROM Answer where QuestionID = 2", db_survey
)

# %%
df_value_counts = df_gender.AnswerText.value_counts()
df_gender_counts = pd.DataFrame(df_value_counts)
df_gender_counts = df_value_counts.reset_index()

# %%
df_gender_counts = df_gender_counts.rename(
    columns={"index": "Gender", "AnswerText": "Count"}
)

# %%
df_gender_counts["Gender"] = df_gender_counts["Gender"].replace(
    {"female": "Female", "male": "Male", "MALE": "Male"}
)
df_gender_counts = df_gender_counts.sort_values("Gender")

# %%
df_gender_counts["Gender"] = np.where(
    (df_gender_counts["Gender"] == "Male") | (df_gender_counts["Gender"] == "Female"),
    df_gender_counts["Gender"],
    "Other",
)

# %%
df_gender_counts.groupby("Gender").sum()
# Out:
#         Count
# Gender
# Female   1024
# Male     3043
# Other     151

# %% [markdown]
# # Question ID 3: What country do you live in?

# %%
df_country = pd.read_sql_query('SELECT AnswerText FROM Answer where QuestionID = 3', db_survey)

# %%
df_country_counts = df_country.AnswerText.value_counts()
df_country_counts = pd.DataFrame(df_country_counts)
df_country_counts = df_country_counts.reset_index()

# %%
df_country_counts = df_country_counts.rename(
    columns={"index": "Country", "AnswerText": "Count"}
)

# %%
df_country_counts["Country"] = df_country_counts["Country"].replace(
    {
        "-1": "Other",
        "Bahamas, The": "Bahamas",
        "United States of America": 'United States'
    }
)

# %%
df_country_counts = df_country_counts.groupby("Country").sum()
df_country_counts = df_country_counts.sort_values("Count", ascending=False)
df_country_counts.head()
# Out:
#                 Count
# Country
# United States    2604
# United Kingdom    482
# Canada            199
# Germany           136
# Netherlands        98

# %% [markdown]
# # Question ID 5: Are you self-employed?

# %%
df_employed = pd.read_sql_query('SELECT DISTINCT AnswerText FROM Answer where QuestionID = 5', db_survey)
df_employed
# Out:
#   AnswerText
# 0         -1
# 1          1
# 2          0

# %%
df_employed['AnswerText'] = df_employed['AnswerText'].str.replace("1", "YES", "-1", "NO")
df_employed
# Out:
#    AnswerText
# 0         NaN
# 1         NaN
# 2         NaN

# %% [markdown]
# # Question ID 6: Do you have a family history of mental illness?

# %%
df_illness = pd.read_sql_query('SELECT DISTINCT AnswerText FROM Answer where QuestionID = 6', db_survey)
df_illness
# Out:
#      AnswerText
# 0            No
# 1           Yes
# 2  I don't know

# %%
df_illness['AnswerText'] = df_illness['AnswerText'].str.replace("I don't know", "Don't Know")
df_illness
# Out:
#    AnswerText
# 0          No
# 1         Yes
# 2  Don't Know
